# %%
import ee
import pwtt

ee.Initialize(project='ggmap-325812')

WAR_START = '2026-03-01'
INFERENCE_START = '2026-03-01'
METHOD = 'ztest'  # 'stouffer', 'max', or 'ztest'

# %%
# Aalma El Chaeb
pwtt.detect_damage(
    aoi=ee.Geometry.Rectangle([35.1798, 33.0897, 35.1846, 33.1016]),
    war_start=WAR_START, inference_start=INFERENCE_START, method=METHOD, viz=True)

# %%
# Ramyeh
pwtt.detect_damage(
    aoi=ee.Geometry.Rectangle([35.3105, 33.1029, 35.3153, 33.1129]),
    war_start=WAR_START, inference_start=INFERENCE_START, method=METHOD, viz=True)

# %%
# Ayta Al-Shab
pwtt.detect_damage(
    aoi=ee.Geometry.Rectangle([35.3218, 33.0863, 35.3384, 33.1048]),
    war_start=WAR_START, inference_start=INFERENCE_START, method=METHOD, viz=True)

# %%
# Bint Jbeil and Maroun el Ras
pwtt.detect_damage(
    aoi=ee.Geometry.Rectangle([35.4244, 33.1067, 35.4497, 33.1242]),
    war_start=WAR_START, inference_start=INFERENCE_START, method=METHOD, viz=True)

# %%
# Aitaroun
pwtt.detect_damage(
    aoi=ee.Geometry.Rectangle([35.4594, 33.1166, 35.4784, 33.1280]),
    war_start=WAR_START, inference_start=INFERENCE_START, method=METHOD, viz=True)

# %%
# Jalal Deirah base
pwtt.detect_damage(
    aoi=ee.Geometry.Point([35.4818, 33.1013]).buffer(500),
    war_start=WAR_START, inference_start=INFERENCE_START, method=METHOD, viz=True)

# %%
# Meiss el Jabal
pwtt.detect_damage(
    aoi=ee.Geometry.Rectangle([35.5163, 33.1593, 35.5186, 33.1914]),
    war_start=WAR_START, inference_start=INFERENCE_START, method=METHOD, viz=True)

# %%
# Houla
pwtt.detect_damage(
    aoi=ee.Geometry.Rectangle([35.5111, 33.2161, 35.5296, 33.2238]),
    war_start=WAR_START, inference_start=INFERENCE_START, method=METHOD, viz=True)

# %%
# Taybeh to Kfar Kela
pwtt.detect_damage(
    aoi=ee.Geometry.Rectangle([35.5163, 33.2770, 35.5636, 33.2868]),
    war_start=WAR_START, inference_start=INFERENCE_START, method=METHOD, viz=True)
